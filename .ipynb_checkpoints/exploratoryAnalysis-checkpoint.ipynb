# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

# %matplotlib inline

# %%
df = pd.read_csv('sfEnergyBenchmarks.csv', thousands=',')
df.columns
# Out:
#     SFPUC Code                                          Facility  \
# 0         1684                               Moscone Center West
# 1          XXX                      Moscone Center North & South
# 2          102                      Bill Graham Civic Auditorium
# 3          XXX      War Memorial Veterans Building & Opera House
# 4          468  Davies Symphony Hall / Zellerbach Rehearsal Hall
# 5          317                         GGP -- Sharon Arts Studio
# 6          378                                    Randall Museum
# 7            3                           SOMArts Cultural Center
# 8          302                   Harvey Milk Center for the Arts
# 9            4           Mission Cultural Center for Latino Arts
# 10           2            African American Art & Culture Complex
# 11           5                               Bayview Opera House
# 12           1             Arts Commission Window Site / Gallery
# 13         236          California Palace of the Legion of Honor
# 14         293                    GGP -- Conservatory of Flowers
# 15        1333                                  Asian Art Museum
# 16         237                                   De Young Museum
# 17         697                    California Academy of Sciences
# 18         292                                        Coit Tower
# 19         412                                       Argonne CDC
# 20        2018                 Zaida T Rodriguez Early Education
# 21          69                     Earl P Mills Community Center
# 22        1104                                       Noriega CDC
# 23         723                          Junipero Serra Annex CDC
# 24        1074                            Commodore Stockton CDC
# 25         420                         Jefferson Early Education
# 26        1014                                  John McLaren CDC
# 27        1910                      Sojourner Truth Child Center
# 28         820                                 Playmates Nursery
# 29        1133                    Leola M Havard Early Education
# ..         ...                                               ...
# 440        207                               Civic Center Garage
# 441       1476                               Union Square Garage
# 442        232                          Portsmouth Square Garage
# 443        234                             Vallejo Street Garage
# 444        706                           Sixteenth & Hoff Garage
# 445       1796                            Music Concourse Garage
# 446        211                             Golden Gateway Garage
# 447       1214                        SF General Hospital Garage
# 448       1235                                  Polk Bush Garage
# 449        233                            Sutter Stockton Garage
# 450        222                            Fifth & Mission Garage
# 451        215                             Moscone Center Garage
# 452        716                   St Mary's Square Parking Garage
# 453        208                            Ellis O'Farrell Garage
# 454        216                           Mission Bartlett Garage
# 455        231                            Performing Arts Garage
# 456       1219       Japan Center Garage - Fillmore Street Annex
# 457       1921                                North Beach Garage
# 458       2039                         SFUSD -- 1340 Bush Garage
# 459        710                             Lombard Street Garage
# 460        213                          Japan Center Main Garage
# 461        509                                    Castro Station
# 462       1221                               Forest Hill Station
# 463        513                               Embarcadero Station
# 464        510                                    Church Station
# 465        554                                    Powell Station
# 466        511                              Civic Center Station
# 467        549                                  Van Ness Station
# 468        504                                Montgomery Station
# 469        485               San Francisco International Airport
#
#                                                  Notes   Dpt.  \
# 0                                                  NaN    CFD
# 1    Adjacent facilities combined for benchmarking,...    CFD
# 2    (2) Bill Graham Civic Auditorium and DPH Centr...    RED
# 3    This location was under construction or vacant...  WMPAC
# 4    Adjacent facilities combined for benchmarking,...  WMPAC
# 5                                                  NaN    RPD
# 6                                                  NaN    RPD
# 7                                                  NaN   SFAC
# 8                                                  NaN    RPD
# 9                                                  NaN   SFAC
# 10                                                 NaN   SFAC
# 11                                                 NaN   SFAC
# 12                                                 NaN   SFAC
# 13                                                 NaN  FAMSF
# 14   Facilities in Golden Gate Park, in cases where...    RPD
# 15                                                 NaN    AAM
# 16                                                 NaN  FAMSF
# 17                                                 NaN    CAS
# 18   This location was under construction or vacant...    RPD
# 19                                                 NaN  SFUSD
# 10                          27.9                      NaN
# 11                           8.8                      NaN
# 12                           8.7                      NaN
# 13                         282.7                      NaN
# 14                         212.2                      NaN
# 15                         194.0                      NaN
# 16                         180.1                      NaN
# 17                         147.5                      NaN
# 18                          54.1                      NaN
# 19                         106.0                      NaN
# 20                         104.4                      NaN
# 21                          61.0                      NaN
# 22                          49.4                      NaN
# 23                          50.0                      NaN
# 24                          48.8                      NaN
# 25                          43.9                      NaN
# 26                          42.7                      NaN
# 27                          38.2                      NaN
# 28                          34.8                      NaN
# 29                          32.3                      NaN
# ..                           ...                      ...
# 440                         13.0                      NaN
# 441                         11.9                      NaN
# 442                          9.6                      NaN
# 443                          9.6                      NaN
# 444                          9.2                      NaN
# 445                          8.4                      NaN
# 446                          8.3                      NaN
# 447                          8.1                      NaN
# 448                          7.8                      NaN
# 449                          7.6                      NaN
# 450                          7.3                      NaN
# 451                          7.2                      NaN
# 452                          7.0                      NaN
# 453                          7.0                      NaN
# 454                          6.6                      NaN
# 455                          6.3                      NaN
# 456                          6.2                      NaN
# 457                          5.5                      NaN
# 458                          5.1                      NaN
# 459                          5.0                      NaN
# 460                          4.9                      NaN
# 461                         77.3                      NaN
# 462                         69.8                      NaN
# 463                         66.3                      NaN
# 464                         56.1                      NaN
# 465                         53.6                      NaN
# 466                         52.1                      NaN
# 467                         51.1                      NaN
# 468                         49.2                      NaN
# 469                         97.4                      NaN
#
# [470 rows x 12 columns]

# %%
eui = '2013 Site EUI (kBtu/sq.ft.)'
buildingArea = '2013 Building Area (sq. ft.)'
yearBuilt = 'Year Built'
buildingCategory = 'General Building Category'

# %% [markdown]
# ## General Building Category Analysis

# %%
meanBuildingCategory_df = df.groupby([buildingCategory]).mean().reset_index().sort_values(eui)
meanBuildingCategory_df.plot(x=buildingCategory, y=eui, kind='bar')

# %% [markdown]
# ## Hospital Category Analysis

# %%
hospital_df = df[df[buildingCategory].isin(['Hospitals'])]
hospital_df
# Out:
#     SFPUC Code                        Facility  \
# 211        192  San Francisco General Hospital
# 212        191           Laguna Honda Hospital
#
#                                                  Notes Dpt.  \
# 211  This location was under construction or vacant...  DPH
# 212  Not qualified for ENERGY STAR rating for hospi...  DPH
#
#     General Building Category Facility Type ENERGY STAR Bldg Type  Year Built  \
# 211                 Hospitals      hospital              Hospital      1915.0
# 212                 Hospitals      hospital              Hospital      1926.0
#
#      Year Renov. 2013 Building Area (sq. ft.)  2013 Site EUI (kBtu/sq.ft.)  \
# 211       1976.0                    1,370,904                        376.6
# 212       2010.0                      717,126                        219.1
#
#     2013 ENERGY STAR rating
# 211                      NaN
# 212                     N.Q.

# %%
labels = hospital_df['Facility']
hospital_df.plot(kind='pie', labels=labels, y=eui)

# %% [markdown]
# ## Build Year Analysis

# %%
df['Year Renov.'].fillna(df[yearBuilt], inplace=True)
constructionYear_df = df.rename(columns={'Year Renov.': 'Year Built/Renovated'})

# %%
buildYear_df = constructionYear_df.groupby(['Year Built/Renovated']).mean()
labels = [
    '1880-1889',
    '1890-1899',
    '1900-1909', 
    '1910-1919', 
    '1920-1929', 
    '1930-1939',
    '1940-1949', 
    '1950-1959', 
    '1960-1969',
    '1970-1979',
    '1980-1989',
    '1990-1999',
    '2000-2009',]
df['year_range'] = pd.cut(constructionYear_df['Year Built/Renovated'], range(1880, 2011, 10), right=False, labels=labels)
byYear = df.groupby(['year_range']).mean()
byYear
# Out:
#              Year Built  Year Renov.  2013 Site EUI (kBtu/sq.ft.)
# year_range
# 1880-1889   1888.000000  1888.000000                     8.800000
# 1890-1899   1895.000000  1895.000000                    40.800000
# 1900-1909   1904.800000  1904.800000                    58.760000
# 1910-1919   1912.826087  1912.826087                    51.686957
# 1920-1929   1924.146341  1924.756098                    51.414634
# 1930-1939   1932.625000  1933.375000                    60.528125
# 1940-1949   1944.941176  1944.941176                    58.005882
# 1950-1959   1952.213115  1954.180328                    61.996721
# 1960-1969   1962.062500  1964.718750                    46.437500
# 1970-1979   1970.274510  1973.960784                    54.913725
# 1980-1989   1965.300000  1985.366667                    53.956667
# 1990-1999   1957.532258  1995.500000                    71.203226
# 2000-2009   1965.626866  2005.134328                    92.285075

# %%
byYear.plot(y=eui)

# %% [markdown]
# ## Regression Analysis of Total Squarefeet to EUI

# %%
filtered_df = df[df[buildingArea] < 200000]
eui_df = filtered_df[[eui]].astype(float)
buildingArea_df = filtered_df[[buildingArea]].astype(float)
model = sm.OLS(eui_df, buildingArea_df).fit()
predictions = model.predict(eui_df)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     2013 Site EUI (kBtu/sq.ft.)   R-squared:                       0.185
# Model:                                     OLS   Adj. R-squared:                  0.183
# Method:                          Least Squares   F-statistic:                     96.37
# Date:                         Fri, 29 Sep 2017   Prob (F-statistic):           1.24e-20
# Time:                                 20:57:48   Log-Likelihood:                -2479.0
# No. Observations:                          425   AIC:                             4960.
# Df Residuals:                              424   BIC:                             4964.
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# 2013 Building Area (sq. ft.)     0.0007   7.63e-05      9.817      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                      275.686   Durbin-Watson:                   0.553
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3654.705
# Skew:                           2.577   Prob(JB):                         0.00
# Kurtosis:                      16.410   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df.plot.scatter(x=buildingArea, y=eui)

# %% [markdown]
# ## Regressional Analysis of Build Year

# %%
year_df = df[[yearBuilt]].astype(float)
year_df
# Out:
#      2013 Site EUI (kBtu/sq.ft.)
# 0                           74.3
# 1                           58.3
# 2                           67.8
# 3                           67.1
# 4                           55.9
# 5                           77.1
# 6                           72.3
# 7                           32.2
# 8                           28.9
# 9                           28.3
# 10                          27.9
# 11                           8.8
# 12                           8.7
# 13                         282.7
# 14                         212.2
# 15                         194.0
# 16                         180.1
# 17                         147.5
# 18                          54.1
# 19                         106.0
# 20                         104.4
# 21                          61.0
# 22                          49.4
# 23                          50.0
# 24                          48.8
# 25                          43.9
# 26                          42.7
# 27                          38.2
# 28                          34.8
# 29                          32.3
# ..                           ...
# 440                         13.0
# 441                         11.9
# 442                          9.6
# 443                          9.6
# 444                          9.2
# 445                          8.4
# 446                          8.3
# 447                          8.1
# 448                          7.8
# 449                          7.6
# 450                          7.3
# 451                          7.2
# 452                          7.0
# 453                          7.0
# 454                          6.6
# 455                          6.3
# 456                          6.2
# 457                          5.5
# 458                          5.1
# 459                          5.0
# 460                          4.9
# 461                         77.3
# 462                         69.8
# 463                         66.3
# 464                         56.1
# 465                         53.6
# 466                         52.1
# 467                         51.1
# 468                         49.2
# 469                         97.4
#
# [470 rows x 1 columns]
